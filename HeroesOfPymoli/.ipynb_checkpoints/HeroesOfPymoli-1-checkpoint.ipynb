# %% [markdown]
# # Pandas Challenge

# %%
import pandas as pd

# %%
# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)
pd.set_option("display.max_rows", None, "display.max_columns", None)
print(purchase_data.columns)
purchase_data
# Out:
# Index(['Purchase ID', 'SN', 'Age', 'Gender', 'Item ID', 'Item Name', 'Price'], dtype='object')
#      Purchase ID               SN  Age                 Gender  Item ID  \
# 0              0          Lisim78   20                   Male      108
# 1              1      Lisovynya38   40                   Male      143
# 2              2       Ithergue48   24                   Male       92
# 3              3    Chamassasya86   24                   Male      100
# 4              4        Iskosia90   23                   Male      131
# 5              5          Yalae81   22                   Male       81
# 6              6        Itheria73   36                   Male      169
# 7              7      Iskjaskst81   20                   Male      162
# 8              8        Undjask33   22                   Male       21
# 9              9      Chanosian48   35  Other / Non-Disclosed      136
# 10            10        Inguron55   23                   Male       95
# ...

# %% [markdown]
# #  Player Count
#
# Display the total number of players

# %%
# Player count

player_count = purchase_data["SN"].value_counts()
player_count_df = str(len(player_count.index))

totplay = pd.DataFrame([[player_count_df]],
                  index=[0], columns=["Total Players"])
totplay = totplay.style.set_properties(**{'text-align': 'left'})
totplay
# Out:
# <style type="text/css">
# #T_2eabc_row0_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_2eabc_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Total Players</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2eabc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2eabc_row0_col0" class="data row0 col0" >576</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Purchasing Analysis (Total)
#
#
# Run basic calculations to obtain number of unique items, average price, etc.
#
# Create a summary data frame to hold the results
#
# Optional: give the displayed data cleaner formatting
#
# Display the summary data frame

# %%
unique_items = purchase_data["Item Name"].unique()
unique_items = purchase_data["Item Name"].value_counts()
numunique = str(len(unique_items.index))
print(numunique)
# Out:
# 179

# %%
avg_price = purchase_data["Price"].mean()
print(avg_price)
# Out:
# 3.050987179487176

# %%
total_purchases = purchase_data["Purchase ID"].value_counts()
tot_purch = str(len(total_purchases.index))
print(len(total_purchases.index))
# Out:
# 780

# %%
total_revenue = purchase_data["Price"].sum()
print(total_revenue)
# Out:
# 2379.77

# %%
uniqueitems_avgp_totp_totr = {
    "Number of Unique Items": [numunique],
    "Average Price": [avg_price],
    "Number of Purchases": [tot_purch],
    "Total Revenue": [total_revenue]
}
All_Data = pd.DataFrame(uniqueitems_avgp_totp_totr)
All_Data_format = All_Data.copy()
All_Data_format["Average Price"] = All_Data_format["Average Price"].map('${:,.2f}'.format)
All_Data_format["Total Revenue"] = All_Data_format["Total Revenue"].map('${:,.2f}'.format)
All_Data_format = All_Data_format.style.set_properties(**{'text-align': 'left'})
All_Data_format
# Out:
# <style type="text/css">
# #T_005a2_row0_col0, #T_005a2_row0_col1, #T_005a2_row0_col2, #T_005a2_row0_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_005a2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Number of Unique Items</th>
#       <th class="col_heading level0 col1" >Average Price</th>
#       <th class="col_heading level0 col2" >Number of Purchases</th>
#       <th class="col_heading level0 col3" >Total Revenue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_005a2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_005a2_row0_col0" class="data row0 col0" >179</td>
#       <td id="T_005a2_row0_col1" class="data row0 col1" >$3.05</td>
#       <td id="T_005a2_row0_col2" class="data row0 col2" >780</td>
#       <td id="T_005a2_row0_col3" class="data row0 col3" >$2,379.77</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Gender Demographics
#
# Percentage and Count of Male Players
#
# Percentage and Count of Female Players
#
# Percentage and Count of Other / Non-Disclosed

# %%
gender_demos = purchase_data[["SN", "Gender"]].value_counts()
gender_demog = pd.DataFrame(gender_demos)

gender_demog = gender_demog.sort_values(by=["Gender"],ascending=False)

gender_demog = gender_demog.reset_index()
gender_demogs = gender_demog["Gender"].value_counts()
gender_demogs = pd.DataFrame(gender_demogs)

gender_demogs.rename(columns={"Gender": "Total Count"}, inplace=True)
gender_demogs = pd.DataFrame(gender_demogs)

totalp = (len(player_count.index))

percent_male = gender_demogs.loc['Male', 'Total Count']/totalp*100
percent_female = gender_demogs.loc['Female', 'Total Count']/totalp*100
percent_other = gender_demogs.loc['Other / Non-Disclosed', 'Total Count']/totalp*100
percent = [percent_male, percent_female, percent_other]
gender_demogs['Percentage of Players'] = percent
gender_demogs['Percentage of Players'] = gender_demogs['Percentage of Players'].map('{:.2f}%'.format)
gender_demogs = gender_demogs.style.set_properties(**{'text-align': 'left'}) 
                                                              
gender_demogs
# Out:
# <style type="text/css">
# #T_9e7ba_row0_col0, #T_9e7ba_row0_col1, #T_9e7ba_row1_col0, #T_9e7ba_row1_col1, #T_9e7ba_row2_col0, #T_9e7ba_row2_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_9e7ba_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Total Count</th>
#       <th class="col_heading level0 col1" >Percentage of Players</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e7ba_level0_row0" class="row_heading level0 row0" >Male</th>
#       <td id="T_9e7ba_row0_col0" class="data row0 col0" >484</td>
#       <td id="T_9e7ba_row0_col1" class="data row0 col1" >84.03%</td>
#     </tr>
#     <tr>
#       <th id="T_9e7ba_level0_row1" class="row_heading level0 row1" >Female</th>
#       <td id="T_9e7ba_row1_col0" class="data row1 col0" >81</td>
#       <td id="T_9e7ba_row1_col1" class="data row1 col1" >14.06%</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# # Purchasing Analysis (Gender)
#
# Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
# Create a summary data frame to hold the results
#
# Optional: give the displayed data cleaner formatting
#
# Display the summary data frame

# %%
pur_analysis = purchase_data[["Gender"]].value_counts()
pur_analysiss = pd.DataFrame(pur_analysis)
pur_analysiss = pur_analysiss.sort_values(by=["Gender"],ascending=True)
pur_analysiss.columns = ['Purchase Count']
purch_analysis = pd.DataFrame(pur_analysiss)


purch_analysis
# Out:
#                        Purchase Count
# Gender
# Female                            113
# Male                              652
# Other / Non-Disclosed              15

# %%
avgpp_males = purch_analysis.loc[['Gender']=="Male"]


avgpp_males
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12640/109663367.py in <module>
# ----> 1 avgpp_males = purch_analysis.loc[['Gender']=="Male"]
#       2
#       3
#       4 avgpp_males
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1161
#    1162         # fall thru to straight lookup
# -> 1163         self._validate_key(key, axis)
#    1164         return self._get_label(key, axis=axis)
#    1165
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
# ...

# %%
avgpp_male = pur_analysis.loc['Gender']=="Male", :]
avgpp_males_df = str(len(avgpp_males.index))
avgpp_males = pd.DataFrame(avgpp_male)
avgpp_male = pur_analysiss.loc['Gender']=="Male", :]
avgpp_female = pur_analysiss.loc['Female', 'Purchase Count']
avgpp_other = pur_analysiss.loc['Other / Non-Disclosed', 'Purchase Count']
avgpp = [avgpp_male, avgpp_female, avgpp_other]
pur_analysiss['Average Purchase Price'] = avgpp
pur_analysiss
